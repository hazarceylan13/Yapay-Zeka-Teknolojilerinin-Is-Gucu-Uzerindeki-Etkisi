# %% [markdown]
# ### MP3 - Veri Toplama Tasarımı
#
# * **Yöntem:** Doküman / İçerik Analizi
# * **Açıklama:** Bu veri seti, proje konusu (Yapay Zekanın İş Gücüne Etkisi) kapsamında çeşitli kurumsal ve akademik raporların analiz edilmesiyle oluşturulmuştur. Tablo, bu raporlardaki nitel bulguların (etkilenme tipi, talep değişimi) ve analizlerin (etki açıklaması) bir sentezidir. Doğrudan rapor analizine dayalı veriler kullanılmıştır.
# * **Kayıt sayısı:** 22 satır
# * **Ana Kaynaklar:**
#     * World Economic Forum (WEF) - 'Future of Jobs Report'
#     * Goldman Sachs - 'The Potentially Large Effects of AI on Economic Growth'
#     * McKinsey Global Institute - 'Generative AI and the future of work'
#     * PwC - 'Global Artificial Intelligence Study'
#     * TİSK - 'Geleceğin İşleri ve Yetkinlikleri Raporu'

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df = pd.read_csv('data_mp3.csv', sep=';', encoding='utf-8-sig')

df.head()
# Out:
#                    Meslek Ünvanı   Sektör Etkilenme Tipi Talep Değişimi  \
# 0  Müşteri Hizmetleri Temsilcisi   Hizmet   Azalma Riski   Yüksek Düşüş
# 1                  İdari Asistan  Yönetim   Azalma Riski   Yüksek Düşüş
# 2             Veri Giriş Elemanı  Yönetim   Azalma Riski   Yüksek Düşüş
# 3              Banka Gişe Memuru   Finans   Azalma Riski   Yüksek Düşüş
# 4             Muhasebeci/Denetçi   Finans   Azalma Riski          Düşüş
#
#                                              Etki Açıklaması  \
# 0          Rutin sorguların chatbotlar tarafından otomasyonu
# 1         Doküman hazırlama ve planlamanın YZ ile otomasyonu
# 2             Veri girişi ve sınıflandırmanın tam otomasyonu
# 3   Online bankacılık ve YZ destekli ATM'lerin yaygınlaşması
# 4  Veri girişi ve rutin denetimlerin YZ tarafından yapılması
#
#                                                                          Veri Kaynağı
# ...
