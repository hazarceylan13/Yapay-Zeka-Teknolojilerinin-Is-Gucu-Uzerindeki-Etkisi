# %% [markdown]
# # MP3 - Veri Toplama Tasarımı
#
# ### Yöntem: Doküman / İçerik Analizi
# Bu çalışmada, proje konusu (Yapay Zekanın İş Gücüne Etkisi) kapsamında **Doküman / İçerik Analizi** yöntemi kullanılmıştır. Çeşitli kurumsal ve akademik raporlar sistematik olarak taranmış ve bulgular iki ayrı veri setinde sentezlenmiştir.
#
# ### Veri Setleri Açıklaması
# Proje kapsamında, analizlerin niteliğine göre **Nitel** ve **Nicel** olmak üzere iki ayrı veri dosyası oluşturulmuştur:
#
# 1.  **Nitel Veri Seti (`data_mp3.csv`):**
#     * **İçerik:** Mesleklerin YZ'den nasıl etkilendiğini (Etkilenme Tipi), talep yönünü (Talep Değişimi) ve etkinin nedenlerini (Etki Açıklaması) içeren sözel analiz tablosudur.
#     * **Kayıt Sayısı:** 32 Satır
#
# 2.  **Nicel Veri Seti (`data_mp3_2.csv`):**
#     * **İçerik:** Mesleklerin otomasyon potansiyeli yüzdesi, YZ'ye maruz kalma skorları (1-100) ve tahmini talep değişim yüzdeleri gibi sayısal verileri içeren istatistiksel tablodur.
#     * **Kayıt Sayısı:** 40 Satır
#
# ### Ana Kaynaklar
# Bu veri setleri aşağıdaki raporların ve akademik çalışmaların sentezlenmesiyle oluşturulmuştur:
# * **World Economic Forum (WEF):** 'Future of Jobs Report' (2024-2025)
# * **Goldman Sachs:** 'The Potentially Large Effects of AI on Economic Growth'
# * **McKinsey Global Institute:** 'Generative AI and the future of work'
# * **PwC:** 'Global Artificial Intelligence Study'
# * **TİSK:** 'Geleceğin İşleri ve Yetkinlikleri Raporu'
# * **OpenAI:** 'GPTs are GPTs: An Early Look at the Labor Market Impact'
# * **Stanford HAI:** 'AI Index Report'

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df = pd.read_csv('data_mp3.csv', sep=';', encoding='utf-8-sig')

df.head()
# Out:
#                    Meslek Ünvanı     Sektör Etkilenme Tipi Talep  Değişimi  \
# 0  Müşteri Hizmetleri Temsilcisi     Hizmet   Azalma Riski    Yüksek Düşüş
# 1                  İdari Asistan    Yönetim   Azalma Riski    Yüksek Düşüş
# 2             Veri Giriş Elemanı    Yönetim   Azalma Riski    Yüksek Düşüş
# 3                        Kasiyer  Perakende   Azalma Riski    Yüksek Düşüş
# 4              Banka Gişe Memuru     Finans   Azalma Riski    Yüksek Düşüş
#
#                                             Etki Açıklaması  \
# 0         Rutin sorguların chatbotlar tarafından otomasyonu
# 1        Doküman hazırlama ve planlamanın YZ ile otomasyonu
# 2            Veri girişi ve sınıflandırmanın tam otomasyonu
# 3          Otomatik ödeme sistemleri ve self-servis kasalar
# 4  Online bankacılık ve YZ destekli ATM'lerin yaygınlaşması
#
#                                                                          Veri Kaynağı
# ...

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df = pd.read_csv('data_mp3_2.csv', sep=';', encoding='utf-8-sig')

df.head()
# Out:
#         Meslek Ünvanı              Sektör  Otomasyon Potansiyeli Yüzdesi  \
# 0      Veri Bilimcisi  Teknoloji/Analitik                             20
# 1       Veri Analisti  Teknoloji/Analitik                             40
# 2     AI Etiği Uzmanı     Teknoloji/Hukuk                             10
# 3  AI Güvenlik Uzmanı  Teknoloji/Güvenlik                              5
# 4    Grafik Tasarımcı             Tasarım                             60
#
#    Yapay Zekaya Maruz Kalma Skorı (1-100)  \
# 0                                      60
# 1                                      85
# 2                                      30
# 3                                      25
# 4                                      75
#
#    Gelecek Talep Değişimi Tahmini (yüzdelik değişim)  \
# 0                                                 30
# 1                                                 22
# 2                                                 45
# ...
